# %%
pip install myqr
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# GENERATE ANY QR CODE USING THE CODE BELOW

# %%
pip install qrcode
# Out:
# ...
# [notice] A new release of pip available: 22.3.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import qrcode
myqr=qrcode.make("https://github.com/Dimrk")
myqr.save("githublink_qr.png")

# %% [markdown]
# DECODE QR CODE USING THE CODE BELOW

# %%
pip install pyzbar
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from pyzbar.pyzbar import decode
from PIL import Image

decode(Image.open("wifi.jpg"))
# Out:
# [Decoded(data=b'WIFI:T:WPA;P:dasumaram;S:NUNGJENG_5G;H:false;', type='QRCODE', rect=Rect(left=262, top=1218, width=553, height=553), polygon=[Point(x=262, y=1218), Point(x=262, y=1771), Point(x=814, y=1770), Point(x=815, y=1218)], quality=1, orientation='UP')]
